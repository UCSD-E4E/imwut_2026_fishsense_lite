# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm.notebook import tqdm
from fishsense_core.laser import calibrate_laser
from scipy import odr

# %% [markdown]
# ## Setup of Simulation
# The following reasonable defaults that match the systems we tested against.

# %%
IMAGE_WIDTH, IMAGE_HEIGHT = 4014, 3016
FOCAL_LENGTH_PX = 2850

IMAGE_WIDTH, IMAGE_HEIGHT, FOCAL_LENGTH_PX
# Out:
# (4014, 3016, 2850)

# %%
camera_intrinsics = np.array([
    [FOCAL_LENGTH_PX, 0, IMAGE_WIDTH / 2],
    [0, FOCAL_LENGTH_PX, IMAGE_HEIGHT / 2],
    [0, 0, 1]
])
inverted_camera_intrinsics = np.linalg.inv(camera_intrinsics)

camera_intrinsics, inverted_camera_intrinsics
# Out:
# (array([[2.850e+03, 0.000e+00, 2.007e+03],
#         [0.000e+00, 2.850e+03, 1.508e+03],
#         [0.000e+00, 0.000e+00, 1.000e+00]]),
#  array([[ 3.50877193e-04,  0.00000000e+00, -7.04210526e-01],
#         [ 0.00000000e+00,  3.50877193e-04, -5.29122807e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]]))

# %%
laser_position = np.array([-0.04, -0.11, 0])
laser_direction = np.array([1e-10, 1e-10, 1])

laser_params = np.concatenate([laser_direction, laser_position[:2]])

laser_position, laser_direction, laser_params
# Out:
# (array([-0.04, -0.11,  0.  ]),
#  array([1.e-10, 1.e-10, 1.e+00]),
#  array([ 1.0e-10,  1.0e-10,  1.0e+00, -4.0e-02, -1.1e-01]))

# %% [markdown]
# ## Next we setup data we can use for testing

# %%
STEP_COUNT = 1000
t = np.linspace(0.5, 30, STEP_COUNT)

STEP_COUNT, t
# Out:
# (1000,
#  array([ 0.5       ,  0.52952953,  0.55905906,  0.58858859,  0.61811812,
#          0.64764765,  0.67717718,  0.70670671,  0.73623624,  0.76576577,
#          0.7952953 ,  0.82482482,  0.85435435,  0.88388388,  0.91341341,
#          0.94294294,  0.97247247,  1.002002  ,  1.03153153,  1.06106106,
#          1.09059059,  1.12012012,  1.14964965,  1.17917918,  1.20870871,
#          1.23823824,  1.26776777,  1.2972973 ,  1.32682683,  1.35635636,
#          1.38588589,  1.41541542,  1.44494494,  1.47447447,  1.504004  ,
#          1.53353353,  1.56306306,  1.59259259,  1.62212212,  1.65165165,
#          1.68118118,  1.71071071,  1.74024024,  1.76976977,  1.7992993 ,
#          1.82882883,  1.85835836,  1.88788789,  1.91741742,  1.94694695,
#          1.97647648,  2.00600601,  2.03553554,  2.06506507,  2.09459459,
#          2.12412412,  2.15365365,  2.18318318,  2.21271271,  2.24224224,
#          2.27177177,  2.3013013 ,  2.33083083,  2.36036036,  2.38988989,
# ...

# %%
p = laser_position[:, np.newaxis] + t[np.newaxis, :] * laser_direction[:, np.newaxis]

p
# Out:
# array([[-0.04      , -0.04      , -0.04      , ..., -0.04      ,
#         -0.04      , -0.04      ],
#        [-0.11      , -0.11      , -0.11      , ..., -0.11      ,
#         -0.11      , -0.11      ],
#        [ 0.5       ,  0.52952953,  0.55905906, ..., 29.94094094,
#         29.97047047, 30.        ]], shape=(3, 1000))

# %%
s = p / p[2, :]
s = camera_intrinsics @ s

s
# Out:
# array([[1.77900000e+03, 1.79171456e+03, 1.80308594e+03, ...,
#         2.00319250e+03, 2.00319626e+03, 2.00320000e+03],
#        [8.81000000e+02, 9.15965029e+02, 9.47236348e+02, ...,
#         1.49752939e+03, 1.49753970e+03, 1.49755000e+03],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00]], shape=(3, 1000))

# %%
s_pixel = np.round(s)

s_pixel
# Out:
# array([[1.779e+03, 1.792e+03, 1.803e+03, ..., 2.003e+03, 2.003e+03,
#         2.003e+03],
#        [8.810e+02, 9.160e+02, 9.470e+02, ..., 1.498e+03, 1.498e+03,
#         1.498e+03],
#        [1.000e+00, 1.000e+00, 1.000e+00, ..., 1.000e+00, 1.000e+00,
#         1.000e+00]], shape=(3, 1000))

# %% [markdown]
# Since our laser produces a line, the projection of the laser line is itself a line in the pinhole camera model.

# %%
plt.scatter(s[0, :], s[1, :], c=p[2, :], cmap='viridis', marker='o')
plt.scatter(s_pixel[0, :], s_pixel[1, :], c=p[2, :], cmap='plasma', marker='o')

# %% [markdown]
# ## Calibration
# Below we go through calibration

# %%
def point_to_plane(point: np.ndarray, std: float = 0.1) -> np.ndarray:
    random_normal = np.random.normal(0, std, (3,))
    random_normal /= np.linalg.norm(random_normal)
    
    if random_normal[2] < 0:
        random_normal = -random_normal

    return point, random_normal

# %%
normals = []

for point in p.T:
    _, normal = point_to_plane(point)

    normals.append(normal)

normals = np.array(normals)
normals
# Out:
# array([[ 0.1336208 , -0.79763894,  0.5881476 ],
#        [-0.45615631, -0.15338564,  0.87658101],
#        [ 0.85374217, -0.51809281,  0.05200152],
#        ...,
#        [-0.97100446, -0.00814382,  0.23892261],
#        [ 0.95311457, -0.1144716 ,  0.28012294],
#        [ 0.12877801,  0.7541676 ,  0.64393124]], shape=(1000, 3))

# %%
def atanasov_calibration_method(ps: np.ndarray):
    """
    Nikolay's method for laser calibration.
    Inputs:
     - ps: the laser points
    Output: the 5-vector of the laser parameters, with the first 3 being the orientation,
            and the final two being the x and y coordinates of the laser origin
    """
    avg_alpha = np.zeros((3,))
    params = np.zeros((5,))
    for i in range(ps.shape[0]):
        for j in range(ps.shape[0]):
            if i != j:
                v = ps[i] - ps[j]
                if v[2] < 0:
                    v = -v
                avg_alpha += v

    avg_alpha /= np.linalg.norm(avg_alpha)
    if avg_alpha[2] < 0:
        avg_alpha = -avg_alpha

    centroid = np.mean(ps, axis=0)
    print(centroid)
    scale_factor = centroid[2] / avg_alpha[2]
    params[0:3] = avg_alpha
    params[3:5] = centroid[0:2] - scale_factor * avg_alpha[0:2]
    return params

# %%
def f(B, x):
    '''Linear function y = m*x + b'''
    # B is a vector of the parameters.
    # x is an array of the current x values.
    # x is in the same format as the x passed to Data or RealData.
    #
    # Return an array in the same format as y passed to Data or RealData.
    return B[0]*x + B[1]

# %%
np.random.seed(0)

calibrations_by_stds = []
stds = [0.0, 0.5, 1.0, 2.0, 5.0, 10.0]

fig, axs = plt.subplots(3, 2)
fig.suptitle('Noisy Points Visualization')

for idx, std in enumerate(tqdm(stds)):
    x, y = divmod(idx, 2)
    ax = axs[x, y]

    s_noisy = np.random.normal(s, std, s.shape)
    rays = inverted_camera_intrinsics @ s_noisy
    scale_factor = np.einsum('ij,ij->j', normals.T, p) / np.einsum('ij,ij->j', normals.T, rays)
    p_noisy = rays * scale_factor

    ax.scatter(s_noisy[0, :], s_noisy[1, :], c='blue', s=1, label='Noisy Points')

    model = odr.Model(f)
    data = odr.Data(s_noisy[0, :], s_noisy[1, :])
    odr_run = odr.ODR(data, model, beta0=[1.0, 1.0])
    results = odr_run.run()

    s_reconstructed = np.zeros_like(s_noisy)
    s_reconstructed[0, :] = results.xplus
    s_reconstructed[1, :] = results.y
    s_reconstructed[2, :] = 1
    rays_reconstructed = inverted_camera_intrinsics @ s_reconstructed
    scale_factor_reconstructed = np.einsum('ij,ij->j', normals.T, p) / np.einsum('ij,ij->j', normals.T, rays_reconstructed)
    p_reconstructed = rays_reconstructed * scale_factor_reconstructed

    s_pixel_noisy = np.random.normal(s_pixel, std, s_pixel.shape)
    s_pixel_noisy = np.round(s_pixel_noisy)
    rays_pixel = inverted_camera_intrinsics @ s_pixel_noisy
    scale_factor_pixel = np.einsum('ij,ij->j', normals.T, p) / np.einsum('ij,ij->j', normals.T, rays_pixel)
    p_pixel_noisy = rays_pixel * scale_factor_pixel

    model_pixel = odr.Model(f)
    data_pixel = odr.Data(s_pixel_noisy[0, :], s_pixel_noisy[1, :])
    odr_run_pixel = odr.ODR(data_pixel, model_pixel, beta0=[1.0, 1.0])
    results_pixel = odr_run_pixel.run()

    s_pixel_reconstructed = np.zeros_like(s_pixel_noisy)
    s_pixel_reconstructed[0, :] = results_pixel.xplus
    s_pixel_reconstructed[1, :] = results_pixel.y
    s_pixel_reconstructed[2, :] = 1
    rays_pixel_reconstructed = inverted_camera_intrinsics @ s_pixel_reconstructed
    scale_pixel_factor_reconstructed = np.einsum('ij,ij->j', normals.T, p) / np.einsum('ij,ij->j', normals.T, rays_pixel_reconstructed)
    p_pixel_reconstructed = rays_pixel_reconstructed * scale_pixel_factor_reconstructed

    calibrations = []
    calibrations_reconstructed = []
    calibrations_pixels = []
    calibrations_reconstructed_pixels = []
    for n in tqdm(list(range(2, STEP_COUNT))):
        idxs = np.random.choice(np.arange(STEP_COUNT), n, replace=False)

        local_laser_origin, local_laser_orientation = calibrate_laser(p_noisy[:, idxs].T)
        calibration_noisy = np.concatenate([local_laser_orientation, local_laser_origin[:2]])

        local_laser_origin_reconstructed, local_laser_orientation_reconstructed = calibrate_laser(p_reconstructed[:, idxs].T)
        calibration_reconstructed = np.concatenate([local_laser_orientation_reconstructed, local_laser_origin_reconstructed[:2]])

        local_laser_origin_pixel, local_laser_orientation_pixel = calibrate_laser(p_pixel_noisy[:, idxs].T)
        calibration_pixel_noisy = np.concatenate([local_laser_orientation_pixel, local_laser_origin_pixel[:2]])

        local_laser_origin_reconstructed_pixel, local_laser_orientation_reconstructed_pixel = calibrate_laser(p_pixel_reconstructed[:, idxs].T)
        calibration_reconstructed_pixel = np.concatenate([local_laser_orientation_reconstructed_pixel, local_laser_origin_reconstructed_pixel[:2]])

        calibrations.append(calibration_noisy)
        calibrations_reconstructed.append(calibration_reconstructed)
        calibrations_pixels.append(calibration_pixel_noisy)
        calibrations_reconstructed_pixels.append(calibration_reconstructed_pixel)

    ax.set_title(f'Noisy Points (Std {std})')
    ax.set_xlabel('Pixel X')
    ax.set_ylabel('Pixel Y')

    ax.scatter(s[0, :], s[1, :], c='purple', s=1, label='Original Points')
    ax.scatter(results.xplus, results.y, c='red', s=1, label='ODR Fit')

    calibrations_by_stds.append((std, calibrations, calibrations_reconstructed, calibrations_pixels, calibrations_reconstructed_pixels))
# Out:
# ...
#   0%|          | 0/998 [00:00<?, ?it/s]

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds:
    percent_error = np.abs((np.array(arrays) - np.tile(laser_params, (len(arrays), 1))) / np.tile(laser_params, (len(arrays), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed) - np.tile(laser_params, (len(arrays_reconstructed), 1))) / np.tile(laser_params, (len(arrays_reconstructed), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds[:3]:
    percent_error = np.abs((np.array(arrays) - np.tile(laser_params, (len(arrays), 1))) / np.tile(laser_params, (len(arrays), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed) - np.tile(laser_params, (len(arrays_reconstructed), 1))) / np.tile(laser_params, (len(arrays_reconstructed), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds[:2]:
    percent_error = np.abs((np.array(arrays) - np.tile(laser_params, (len(arrays), 1))) / np.tile(laser_params, (len(arrays), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed) - np.tile(laser_params, (len(arrays_reconstructed), 1))) / np.tile(laser_params, (len(arrays_reconstructed), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds:
    percent_error = np.abs((np.array(arrays_pixel) - np.tile(laser_params, (len(arrays_pixel), 1))) / np.tile(laser_params, (len(arrays_pixel), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed_pixel) - np.tile(laser_params, (len(arrays_reconstructed_pixel), 1))) / np.tile(laser_params, (len(arrays_reconstructed_pixel), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds[:3]:
    percent_error = np.abs((np.array(arrays_pixel) - np.tile(laser_params, (len(arrays_pixel), 1))) / np.tile(laser_params, (len(arrays_pixel), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed_pixel) - np.tile(laser_params, (len(arrays_reconstructed_pixel), 1))) / np.tile(laser_params, (len(arrays_reconstructed_pixel), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds[:2]:
    percent_error = np.abs((np.array(arrays_pixel) - np.tile(laser_params, (len(arrays_pixel), 1))) / np.tile(laser_params, (len(arrays_pixel), 1)) * 100)
    percent_error_reconstructed = np.abs((np.array(arrays_reconstructed_pixel) - np.tile(laser_params, (len(arrays_reconstructed_pixel), 1))) / np.tile(laser_params, (len(arrays_reconstructed_pixel), 1)) * 100)

    direction_percent_error = percent_error[:, ][:, 0:3]
    position_percent_error = np.mean(percent_error[:, ][:, 3:5], axis=1)

    direction_percent_error_reconstructed = percent_error_reconstructed[:, ][:, 0:3]
    position_percent_error_reconstructed = np.mean(percent_error_reconstructed[:, ][:, 3:5], axis=1)

    # plt.plot(np.arange(2, STEP_COUNT), position_percent_error, label=f'Std {std} Position Percent Error')
    plt.plot(np.arange(2, STEP_COUNT)[100:], position_percent_error_reconstructed[100:], linestyle='dashed', label=f'Std {std} Position Percent Error (Reconstructed)')

plt.title('Position Percent Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Percent Error')
plt.legend()

# %% [markdown]
# ## Testing Each Calibration

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays, arrays_reconstructed):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT), mean_errors_noisy, label=f'Std {std} Mean Reconstruction Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT), mean_errors_reconstructed, label=f'Std {std} Mean Reconstruction Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds[:2]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays, arrays_reconstructed):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT), mean_errors_noisy, label=f'Std {std} Mean Reconstruction Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT), mean_errors_reconstructed, label=f'Std {std} Mean Reconstruction Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _, _ in calibrations_by_stds[:2]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays, arrays_reconstructed):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Reconstruction Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Reconstruction Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _ in calibrations_by_stds:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays, arrays_reconstructed):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.abs((world_points_reconstructed - p)[2, :])) * 100

        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Z Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Z Percent Error (Reconstructed)')

plt.title('Mean Z Percent Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Z Percent Error (%)')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays_pixel, arrays_reconstructed_pixel):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT), mean_errors_noisy, label=f'Std {std} Mean Reconstruction Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT), mean_errors_reconstructed, label=f'Std {std} Mean Reconstruction Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds[:2]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays_pixel, arrays_reconstructed_pixel):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT), mean_errors_noisy, label=f'Std {std} Mean Reconstruction Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT), mean_errors_reconstructed, label=f'Std {std} Mean Reconstruction Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds[:2]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays_pixel, arrays_reconstructed_pixel):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.sqrt(np.sum((world_points_reconstructed - p) ** 2, axis=1)))
        
        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Z Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Z Percent Error (Reconstructed)')

plt.title('Mean Reconstruction Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Reconstruction Error (m)')
plt.legend()

# %%
for std, arrays, arrays_reconstructed, _ in calibrations_by_stds[:2]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays, arrays_reconstructed):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.abs((world_points_reconstructed - p)[2, :])) * 100

        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Z Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Z Percent Error (Reconstructed)')

plt.title('Mean Z Percent Error vs Number of Points Used for Calibration (Continuous)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Z Percent Error (%)')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays_pixel, arrays_reconstructed_pixel):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.abs((world_points_reconstructed - p)[2, :])) * 100

        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Z Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Z Percent Error (Reconstructed)')

plt.title('Mean Z Percent Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Z Percent Error (%)')
plt.legend()

# %%
for std, _, _, arrays_pixel, arrays_reconstructed_pixel in calibrations_by_stds[:3]:
    mean_errors_noisy = []
    mean_errors_reconstructed = []

    for calibration_noisy, calibration_reconstructed in zip(arrays_pixel, arrays_reconstructed_pixel):
        laser_axis_noisy = calibration_noisy[0:3]
        
        laser_origin_noisy = np.zeros((3,))
        laser_origin_noisy[0:2] = calibration_noisy[3:5]
        laser_origin_noisy[2] = 0.0

        laser_axis_reconstructed = calibration_reconstructed[0:3]

        laser_origin_reconstructed = np.zeros((3,))
        laser_origin_reconstructed[0:2] = calibration_reconstructed[3:5]
        laser_origin_reconstructed[2] = 0.0

        projected_points = inverted_camera_intrinsics @ s
        norms = np.linalg.norm(projected_points, axis=0)
        final_laser_axis = -projected_points / norms

        point_constants_noisy = (
				(final_laser_axis.T @ laser_origin_noisy)
			 	- (laser_axis_noisy.T @ laser_origin_noisy) * (laser_axis_noisy.T @ final_laser_axis)
			) / (1 - (laser_axis_noisy.T @ final_laser_axis) ** 2)
        world_points_noisy = np.tile(point_constants_noisy, (3, 1)) * final_laser_axis
        mean_error_noisy = np.mean(np.sqrt(np.sum((world_points_noisy - p) ** 2, axis=1)))

        point_constants_reconstructed = (
                (final_laser_axis.T @ laser_origin_reconstructed)
                - (laser_axis_reconstructed.T @ laser_origin_reconstructed) * (laser_axis_reconstructed.T @ final_laser_axis)
            ) / (1 - (laser_axis_reconstructed.T @ final_laser_axis) ** 2)
        world_points_reconstructed = np.tile(point_constants_reconstructed, (3, 1)) * final_laser_axis
        mean_error_reconstructed = np.mean(np.abs((world_points_reconstructed - p)[2, :])) * 100

        mean_errors_noisy.append(mean_error_noisy)
        mean_errors_reconstructed.append(mean_error_reconstructed)

    # plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_noisy[800:], label=f'Std {std} Mean Z Error (Noisy)')
    plt.plot(np.arange(2, STEP_COUNT)[800:], mean_errors_reconstructed[800:], label=f'Std {std} Mean Z Percent Error (Reconstructed)')

plt.title('Mean Z Percent Error vs Number of Points Used for Calibration (Discrete Pixels)')
plt.xlabel('Number of Points Used for Calibration')
plt.ylabel('Mean Z Percent Error (%)')
plt.legend()
